# %% [markdown]
# ## Wind Energy Data Clean-up

# %% [markdown]
# Import dependencies, data files and setup

# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load
storm_data_to_load = "Resources/bom.australia.storm.archive.csv"

# Read Storm Data File and store into Pandas DataFrames
storm_data = pd.read_csv(storm_data_to_load, encoding='iso8859_2')

# %%
storm_data.head()
# Out:
#    Event ID Database    ID       Date/Time           Nearest town State  \
# 0     23725     Wind  5620  3/01/2010 1:30               ARMIDALE   NSW
# 1     23726     Rain  3377  4/01/2010 6:25               INVERELL   NSW
# 2     23727     Wind  5621  5/01/2010 0:43  WAGGA WAGGA AERODROME   NSW
# 3     23728     Rain  3378  5/01/2010 8:00             SPRINGWOOD   NSW
# 4     23729     Rain  3379  5/01/2010 7:00             CANOWINDRA   NSW
#
#    Latitude  Longitude                                           Comments  \
# 0  -30.5151   151.6650  Weatherzone photos near Armidale showed trees ...
# 1  -29.7817   151.1178  Spotter reported 58mm of rain about 11km north...
# 2  -35.1318   147.4179  51 knot  gust recorded at Wagga Wagga airport ...
# 3  -33.6984   150.5679  Spotter reported 50mm of rain at Springwood st...
# 4  -33.5651   148.6512  Spotter reported 30mm of rain at Canowindra in...
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN         NaN         NaN
